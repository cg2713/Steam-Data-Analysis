# %%
#libary imports
import pandas as pd

# %%
page1 = 30
new_dataframe = pd.concat(
    map(pd.read_csv, ['steam_data_first_half.csv','./steam_data_final_half.csv']), ignore_index=True)
    #map(pd.read_csv, ['steam_data_first_half.csv',f'../{page1}/steamdata{page1}.csv']), ignore_index=True)
# Out:
# c:\Users\2713c\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\concat.py:294: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   op = _Concatenator(

# %%
new_dataframe.head()
# Out:
#    Unnamed: 0  steam_appid  type                     name_x required_age  \
# 0         0.0           10  game             Counter-Strike            0
# 1         1.0           20  game      Team Fortress Classic            0
# 2         2.0           30  game              Day of Defeat            0
# 3         3.0           40  game         Deathmatch Classic            0
# 4         4.0           50  game  Half-Life: Opposing Force            0
#
#   is_free controller_support  dlc  \
# 0   False                NaN  NaN
# 1   False                NaN  NaN
# 2   False                NaN  NaN
# 3   False                NaN  NaN
# 4   False                NaN  NaN
#
#                                 detailed_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# ...

# %%
#CV_Merge1 = CV_Merge1.drop(['org_name', 'country_code_y', 'state_code_y', 'num_exits', 'closed_on'], axis = 1)  # Remove unwanted/duplicate columns. Type as dict. Ex ['col1', 'col2', 'col5']

#CV_Merge1.head()  # Check outcome

# %%
new_dataframe_1 = new_dataframe.drop(['Unnamed: 0'], axis = 1)  # Remove unwanted/duplicate columns. Type as dict. Ex ['col1', 'col2', 'col5']

new_dataframe_1.head()  # Check outcome
# Out:
#    steam_appid  type                     name_x required_age is_free  \
# 0           10  game             Counter-Strike            0   False
# 1           20  game      Team Fortress Classic            0   False
# 2           30  game              Day of Defeat            0   False
# 3           40  game         Deathmatch Classic            0   False
# 4           50  game  Half-Life: Opposing Force            0   False
#
#   controller_support  dlc                               detailed_description  \
# 0                NaN  NaN  Play the world's number 1 online action game. ...
# 1                NaN  NaN  One of the most popular online action games of...
# 2                NaN  NaN  Enlist in an intense brand of Axis vs. Allied ...
# 3                NaN  NaN  Enjoy fast-paced multiplayer gaming with Death...
# 4                NaN  NaN  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# ...

# %%
new_dataframe_1.to_csv("steam_data_first_half.csv")

# %%
new_dataframe_1.info()
page1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62043 entries, 0 to 62042
# Data columns (total 58 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   steam_appid              62043 non-null  int64
#  1   type                     61948 non-null  object
#  2   name_x                   62034 non-null  object
#  3   required_age             61948 non-null  object
#  4   is_free                  61948 non-null  object
#  5   controller_support       13375 non-null  object
#  6   dlc                      10335 non-null  object
#  7   detailed_description     61901 non-null  object
#  8   about_the_game           61900 non-null  object
#  9   short_description        61906 non-null  object
#  10  fullgame                 0 non-null      float64
#  11  supported_languages      61916 non-null  object
#  12  header_image             61948 non-null  object
#  13  website                  33087 non-null  object
# ...
