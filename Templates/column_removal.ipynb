# %%
import pandas as pd

# %%
file = './steam_data_full.csv'
dest1 = './steam_data_cleaned_phase_1.csv'

# %%
dataframe = pd.read_csv(file)
# Out:
# c:\Users\2713c\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
dataframe
# Out:
#        Unnamed: 0  steam_appid  type                      name_x required_age  \
# 0               0           10  game              Counter-Strike            0
# 1               1           20  game       Team Fortress Classic            0
# 2               2           30  game               Day of Defeat            0
# 3               3           40  game          Deathmatch Classic            0
# 4               4           50  game   Half-Life: Opposing Force            0
# ...           ...          ...   ...                         ...          ...
# 62038       62038       889680  game                         Her          0.0
# 62039       62039       920450  game        Escape The Labyrinth          0.0
# 62040       62040      1033250  game  BluBoy: The Journey Begins          0.0
# 62041       62041      1081600  game          Fractal Gallery VR          0.0
# 62042       62042      2196320  game           Space Yugoslav 2D          0.0
#
# ...

# %%
cleaned_dataframe = dataframe.drop(['languages', 'discount', 'initialprice', 'name_y', 'content_descriptors',
                                    'support_info','achievements','movies','screenshots', 'platforms',
                                    'package_groups','packages','demos','ext_user_account_notice','drm_notice',
                                    'legal_notice','pc_requirements','mac_requirements', 'linux_requirements','website',
                                    'supported_languages','header_image','fullgame','short_description','about_the_game',
                                    'detailed_description','dlc','controller_support','required_age','type','background',
                                    'developers','publishers','genres','score_rank','userscore','reviews'], axis = 1)  # Remove unwanted/duplicate columns. Type as dict. Ex ['col1', 'col2', 'col5']

#CV_Merge1.head()  # Check outcome

# %%
cleaned_dataframe.head()
# Out:
#    Unnamed: 0  steam_appid                     name_x is_free  \
# 0           0           10             Counter-Strike   False
# 1           1           20      Team Fortress Classic   False
# 2           2           30              Day of Defeat   False
# 3           3           40         Deathmatch Classic   False
# 4           4           50  Half-Life: Opposing Force   False
#
#                                       price_overview  \
# 0  {'currency': 'USD', 'initial': 999, 'final': 9...
# 1  {'currency': 'USD', 'initial': 499, 'final': 4...
# 2  {'currency': 'USD', 'initial': 499, 'final': 4...
# 3  {'currency': 'USD', 'initial': 499, 'final': 4...
# 4  {'currency': 'USD', 'initial': 499, 'final': 4...
#
#                                           metacritic  \
# 0  {'score': 88, 'url': 'https://www.metacritic.c...
# 1                                                NaN
# 2  {'score': 79, 'url': 'https://www.metacritic.c...
# ...

# %%
# Save the dataframe to a csv file
cleaned_dataframe.to_csv(dest1)
